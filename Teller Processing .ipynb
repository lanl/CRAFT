# %%
#import xarray as xr
import numpy as np 
import pandas as pd
import os

# %%
vars1=["Date","Model",'TLAI','QVEGE',
       'QVEGT','QSOIL','FATES_GPP','FATES_LAI_CANOPY_SZPF_0','FATES_LAI_CANOPY_SZPF_0','FATES_LAI_CANOPY_SZPF_1',
       'FATES_LAI_CANOPY_SZPF_2','FATES_LAI_CANOPY_SZPF_3','FATES_LAI_CANOPY_SZPF_4','FATES_LAI_CANOPY_SZPF_5',
       'FATES_LAI_CANOPY_SZPF_6','FATES_LAI_CANOPY_SZPF_7','FATES_LAI_CANOPY_SZPF_8','FATES_LAI_CANOPY_SZPF_9',
       'FATES_LAI_CANOPY_SZPF_10','FATES_LAI_CANOPY_SZPF_11','FATES_LAI_CANOPY_SZPF_12','FATES_LAI_CANOPY_SZPF_13',
        'FATES_LAI_CANOPY_SZPF_14','FATES_LAI_CANOPY_SZPF_15','FATES_LAI_CANOPY_SZPF_16','FATES_LAI_CANOPY_SZPF_17',
        'FATES_LAI_CANOPY_SZPF_18','FATES_LAI_CANOPY_SZPF_19','FATES_LAI_CANOPY_SZPF_20','FATES_LAI_CANOPY_SZPF_21',
        'FATES_LAI_CANOPY_SZPF_22','FATES_LAI_CANOPY_SZPF_23','FATES_LAI_USTORY_SZPF_0','FATES_LAI_USTORY_SZPF_1',
       'FATES_LAI_USTORY_SZPF_2','FATES_LAI_USTORY_SZPF_3','FATES_LAI_USTORY_SZPF_4','FATES_LAI_USTORY_SZPF_5',
       'FATES_LAI_USTORY_SZPF_6','FATES_LAI_USTORY_SZPF_7','FATES_LAI_USTORY_SZPF_8','FATES_LAI_USTORY_SZPF_9',
       'FATES_LAI_USTORY_SZPF_10','FATES_LAI_USTORY_SZPF_11','FATES_LAI_USTORY_SZPF_12','FATES_LAI_USTORY_SZPF_13',
        'FATES_LAI_USTORY_SZPF_14','FATES_LAI_USTORY_SZPF_15','FATES_LAI_USTORY_SZPF_16','FATES_LAI_USTORY_SZPF_17',
        'FATES_LAI_USTORY_SZPF_18','FATES_LAI_USTORY_SZPF_19','FATES_LAI_USTORY_SZPF_20','FATES_LAI_USTORY_SZPF_21',
        'FATES_LAI_USTORY_SZPF_22','FATES_LAI_USTORY_SZPF_23','FATES_VEGC_ABOVEGROUND_x','FATES_VEGC_PF_2','FATES_VEGC_PF_1',
        'H2OSOIvalue1','H2OSOIvalue2','H2OSOIvalue3','H2OSOIvalue4']

vars1=["Date","Model",'TLAI','QVEGE',
       'QVEGT','QSOIL','FATES_GPP','FATES_LAI_CANOPY_SZPF_0','FATES_LAI_CANOPY_SZPF_0','FATES_LAI_CANOPY_SZPF_1',
       'FATES_LAI_CANOPY_SZPF_2','FATES_LAI_CANOPY_SZPF_3','FATES_LAI_CANOPY_SZPF_4','FATES_LAI_CANOPY_SZPF_5',
       'FATES_LAI_CANOPY_SZPF_6','FATES_LAI_CANOPY_SZPF_7','FATES_LAI_CANOPY_SZPF_8','FATES_LAI_CANOPY_SZPF_9',
       'FATES_LAI_CANOPY_SZPF_10','FATES_LAI_CANOPY_SZPF_11','FATES_LAI_CANOPY_SZPF_12','FATES_LAI_CANOPY_SZPF_13',
        'FATES_LAI_CANOPY_SZPF_14','FATES_LAI_CANOPY_SZPF_15','FATES_LAI_CANOPY_SZPF_16','FATES_LAI_CANOPY_SZPF_17',
        'FATES_LAI_CANOPY_SZPF_18','FATES_LAI_CANOPY_SZPF_19','FATES_LAI_CANOPY_SZPF_20','FATES_LAI_CANOPY_SZPF_21',
        'FATES_LAI_CANOPY_SZPF_22','FATES_LAI_CANOPY_SZPF_23','FATES_LAI_USTORY_SZPF_0','FATES_LAI_USTORY_SZPF_1',
       'FATES_LAI_USTORY_SZPF_2','FATES_LAI_USTORY_SZPF_3','FATES_LAI_USTORY_SZPF_4','FATES_LAI_USTORY_SZPF_5',
       'FATES_LAI_USTORY_SZPF_6','FATES_LAI_USTORY_SZPF_7','FATES_LAI_USTORY_SZPF_8','FATES_LAI_USTORY_SZPF_9',
       'FATES_LAI_USTORY_SZPF_10','FATES_LAI_USTORY_SZPF_11','FATES_LAI_USTORY_SZPF_12','FATES_LAI_USTORY_SZPF_13',
        'FATES_LAI_USTORY_SZPF_14','FATES_LAI_USTORY_SZPF_15','FATES_LAI_USTORY_SZPF_16','FATES_LAI_USTORY_SZPF_17',
        'FATES_LAI_USTORY_SZPF_18','FATES_LAI_USTORY_SZPF_19','FATES_LAI_USTORY_SZPF_20','FATES_LAI_USTORY_SZPF_21',
        'FATES_LAI_USTORY_SZPF_22','FATES_LAI_USTORY_SZPF_23','FATES_VEGC_ABOVEGROUND_x','FATES_VEGC_PF_2','FATES_VEGC_PF_1',
        'H2OSOIvalue1','H2OSOIvalue2','H2OSOIvalue3','H2OSOIvalue4']

# %%
'TLAI','QVEGE',
       'QVEGT','QSOIL','FATES_GPP','FATES_LAI_CANOPY_SZPF_0','FATES_LAI_CANOPY_SZPF_0','FATES_LAI_CANOPY_SZPF_1',
       'FATES_LAI_CANOPY_SZPF_2','FATES_LAI_CANOPY_SZPF_3','FATES_LAI_CANOPY_SZPF_4','FATES_LAI_CANOPY_SZPF_5',
       'FATES_LAI_CANOPY_SZPF_6','FATES_LAI_CANOPY_SZPF_7','FATES_LAI_CANOPY_SZPF_8','FATES_LAI_CANOPY_SZPF_9',
       'FATES_LAI_CANOPY_SZPF_10','FATES_LAI_CANOPY_SZPF_11','FATES_LAI_CANOPY_SZPF_12','FATES_LAI_CANOPY_SZPF_13',
        'FATES_LAI_CANOPY_SZPF_14','FATES_LAI_CANOPY_SZPF_15','FATES_LAI_CANOPY_SZPF_16','FATES_LAI_CANOPY_SZPF_17',
        'FATES_LAI_CANOPY_SZPF_18','FATES_LAI_CANOPY_SZPF_19','FATES_LAI_CANOPY_SZPF_20','FATES_LAI_CANOPY_SZPF_21',
        'FATES_LAI_CANOPY_SZPF_22','FATES_LAI_CANOPY_SZPF_23','FATES_LAI_USTORY_SZPF_0','FATES_LAI_USTORY_SZPF_1',
       'FATES_LAI_USTORY_SZPF_2','FATES_LAI_USTORY_SZPF_3','FATES_LAI_USTORY_SZPF_4','FATES_LAI_USTORY_SZPF_5',
       'FATES_LAI_USTORY_SZPF_6','FATES_LAI_USTORY_SZPF_7','FATES_LAI_USTORY_SZPF_8','FATES_LAI_USTORY_SZPF_9',
       'FATES_LAI_USTORY_SZPF_10','FATES_LAI_USTORY_SZPF_11','FATES_LAI_USTORY_SZPF_12','FATES_LAI_USTORY_SZPF_13',
        'FATES_LAI_USTORY_SZPF_14','FATES_LAI_USTORY_SZPF_15','FATES_LAI_USTORY_SZPF_16','FATES_LAI_USTORY_SZPF_17',
        'FATES_LAI_USTORY_SZPF_18','FATES_LAI_USTORY_SZPF_19','FATES_LAI_USTORY_SZPF_20','FATES_LAI_USTORY_SZPF_21',
        'FATES_LAI_USTORY_SZPF_22','FATES_LAI_USTORY_SZPF_23'

# %%
Runs=list(range(1,500))
wdir="C:/Users/345578/Desktop/Teller_LHS_sampler/output_Teller/output_Tell_72925/output2_Teller_Sens_run.IELMFATES/"
wdir="C:/Users/345578/Desktop/Fixedfinally925/outputtest_Teller_Sens_run.IELMFATES/"
case="Teller_Sens_run.IELMFATES"

vars1=["Date","Model",'FATES_VEGC_ABOVEGROUND_x','TLAI','QVEGE',
       'QVEGT','QSOIL','FATES_GPP','FATES_LAI_CANOPY_SZPF_0','FATES_LAI_CANOPY_SZPF_0','FATES_LAI_CANOPY_SZPF_1',
       'FATES_LAI_CANOPY_SZPF_2','FATES_LAI_CANOPY_SZPF_3','FATES_LAI_CANOPY_SZPF_4','FATES_LAI_CANOPY_SZPF_5',
       'FATES_LAI_CANOPY_SZPF_6','FATES_LAI_CANOPY_SZPF_7','FATES_LAI_CANOPY_SZPF_8','FATES_LAI_CANOPY_SZPF_9',
       'FATES_LAI_CANOPY_SZPF_10','FATES_LAI_CANOPY_SZPF_11','FATES_LAI_CANOPY_SZPF_12','FATES_LAI_CANOPY_SZPF_13',
        'FATES_LAI_CANOPY_SZPF_14','FATES_LAI_CANOPY_SZPF_15','FATES_LAI_CANOPY_SZPF_16','FATES_LAI_CANOPY_SZPF_17',
        'FATES_LAI_CANOPY_SZPF_18','FATES_LAI_CANOPY_SZPF_19','FATES_LAI_CANOPY_SZPF_20','FATES_LAI_CANOPY_SZPF_21',
        'FATES_LAI_CANOPY_SZPF_22','FATES_LAI_CANOPY_SZPF_23','FATES_LAI_USTORY_SZPF_0','FATES_LAI_USTORY_SZPF_1',
       'FATES_LAI_USTORY_SZPF_2','FATES_LAI_USTORY_SZPF_3','FATES_LAI_USTORY_SZPF_4','FATES_LAI_USTORY_SZPF_5',
       'FATES_LAI_USTORY_SZPF_6','FATES_LAI_USTORY_SZPF_7','FATES_LAI_USTORY_SZPF_8','FATES_LAI_USTORY_SZPF_9',
       'FATES_LAI_USTORY_SZPF_10','FATES_LAI_USTORY_SZPF_11','FATES_LAI_USTORY_SZPF_12','FATES_LAI_USTORY_SZPF_13',
        'FATES_LAI_USTORY_SZPF_14','FATES_LAI_USTORY_SZPF_15','FATES_LAI_USTORY_SZPF_16','FATES_LAI_USTORY_SZPF_17',
        'FATES_LAI_USTORY_SZPF_18','FATES_LAI_USTORY_SZPF_19','FATES_LAI_USTORY_SZPF_20','FATES_LAI_USTORY_SZPF_21',
        'FATES_LAI_USTORY_SZPF_22','FATES_LAI_USTORY_SZPF_23',
        'H2OSOIvalue1','FATES_VEGC_PF_2','FATES_VEGC_PF_1','FATES_MORTALITY_HYDRAULIC_SZ_0.0_x'
,'FATES_MORTALITY_BACKGROUND_SZ_0.0','H2OSOIvalue3','FATES_MORTALITY_CSTARV_SZ_0.0',"FATES_MORTALITY_PF_1_x","FATES_MORTALITY_PF_2_x","FATES_MORTALITY_FREEZING_SZ_0.0"]



out=pd.DataFrame([])
for b in Runs: 
    print(wdir+case+str(b)+".csv")
    if os.path.exists(wdir+case+str(b)+".csv"):
        print("LOADED"+str(b))
        Site1=pd.read_csv(wdir+case+str(b)+".csv")
        out=out.append(Site1[vars1])
        
for var in vars1:        
    print(var)
    GPP=out[["Date",var,"Model"]]
    GPP.to_csv(wdir+case+"_"+var+"_500.csv")
# Out:
# C:/Users/345578/Desktop/Fixedfinally925/outputtest_Teller_Sens_run.IELMFATES/Teller_Sens_run.IELMFATES1.csv
# LOADED1
# C:/Users/345578/Desktop/Fixedfinally925/outputtest_Teller_Sens_run.IELMFATES/Teller_Sens_run.IELMFATES2.csv
# LOADED2
# C:/Users/345578/Desktop/Fixedfinally925/outputtest_Teller_Sens_run.IELMFATES/Teller_Sens_run.IELMFATES3.csv
# LOADED3
# C:/Users/345578/Desktop/Fixedfinally925/outputtest_Teller_Sens_run.IELMFATES/Teller_Sens_run.IELMFATES4.csv
# LOADED4
# C:/Users/345578/Desktop/Fixedfinally925/outputtest_Teller_Sens_run.IELMFATES/Teller_Sens_run.IELMFATES5.csv
# LOADED5
# C:/Users/345578/Desktop/Fixedfinally925/outputtest_Teller_Sens_run.IELMFATES/Teller_Sens_run.IELMFATES6.csv
# LOADED6
# C:/Users/345578/Desktop/Fixedfinally925/outputtest_Teller_Sens_run.IELMFATES/Teller_Sens_run.IELMFATES7.csv
# LOADED7
# C:/Users/345578/Desktop/Fixedfinally925/outputtest_Teller_Sens_run.IELMFATES/Teller_Sens_run.IELMFATES8.csv
# LOADED8
# ...

# %%
out.max()
# Out:
# Date                        2101-12-31 00:00:00
# Model                                        99
# FATES_LAI_USTORY_SZPF_0                0.003811
# FATES_LAI_USTORY_SZPF_1                     0.0
# FATES_LAI_USTORY_SZPF_11                    0.0
# FATES_LAI_USTORY_SZPF_12                    0.0
# FATES_LAI_USTORY_SZPF_13                    0.0
# dtype: object

# %%
vars1=['FATES_LAI_CANOPY_SZPF_13',
        'FATES_LAI_CANOPY_SZPF_14','FATES_LAI_CANOPY_SZPF_15','FATES_LAI_CANOPY_SZPF_16','FATES_LAI_CANOPY_SZPF_17',
        'FATES_LAI_CANOPY_SZPF_18','FATES_LAI_CANOPY_SZPF_19','FATES_LAI_CANOPY_SZPF_20','FATES_LAI_CANOPY_SZPF_21',
        'FATES_LAI_CANOPY_SZPF_22','FATES_LAI_CANOPY_SZPF_23']
for var in vars1:        
    GPP=out[["Date",var,"Model"]]
    GPP.to_csv(wdir+case+"_"+var+"_1000.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-209e2b33decb> in <module>
#       4         'FATES_LAI_CANOPY_SZPF_22','FATES_LAI_CANOPY_SZPF_23']
#       5 for var in vars1:
# ----> 6     GPP=out[["Date",var,"Model"]]
#       7     GPP.to_csv(wdir+case+"_"+var+"_1000.csv")
#
# ~\Anaconda3\envs\NCDF\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3459             if is_iterator(key):
#    3460                 key = list(key)
# -> 3461             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3462
#    3463         # take() does not accept boolean indexers
#
# ~\Anaconda3\envs\NCDF\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# ...

# %%
Runs=list(range(1,1000))
wdir="C:/Users/345578/Desktop/Teller_LHS_sampler/output_Teller/Runs612/output2_Teller/"
case="Teller_Graminoid_D_Shrub_no_comp_daily_043025.IELMFATES"

vars1=["Date","Model",'H2OSOIvalue1','H2OSOIvalue3']

out=pd.DataFrame([])
for b in Runs: 
    print(wdir+case+str(b)+".csv")
    if os.path.exists(wdir+case+str(b)+".csv"):
        print(b)
        Site1=pd.read_csv(wdir+case+str(b)+".csv")
        out=out.append(Site1[vars1])
        
for var in vars1:        
    GPP=out[["Date",var,"Model"]]
    GPP.to_csv(wdir+case+"_"+var+"_1000.csv")
# Out:
# C:/Users/345578/Desktop/Teller_LHS_sampler/output_Teller/Runs612/output2_Teller/Teller_Graminoid_D_Shrub_no_comp_daily_043025.IELMFATES1.csv
# 1
# C:/Users/345578/Desktop/Teller_LHS_sampler/output_Teller/Runs612/output2_Teller/Teller_Graminoid_D_Shrub_no_comp_daily_043025.IELMFATES2.csv
# 2
# C:/Users/345578/Desktop/Teller_LHS_sampler/output_Teller/Runs612/output2_Teller/Teller_Graminoid_D_Shrub_no_comp_daily_043025.IELMFATES3.csv
# 3
# C:/Users/345578/Desktop/Teller_LHS_sampler/output_Teller/Runs612/output2_Teller/Teller_Graminoid_D_Shrub_no_comp_daily_043025.IELMFATES4.csv
# 4
# C:/Users/345578/Desktop/Teller_LHS_sampler/output_Teller/Runs612/output2_Teller/Teller_Graminoid_D_Shrub_no_comp_daily_043025.IELMFATES5.csv
# 5
# C:/Users/345578/Desktop/Teller_LHS_sampler/output_Teller/Runs612/output2_Teller/Teller_Graminoid_D_Shrub_no_comp_daily_043025.IELMFATES6.csv
# 6
# ...
