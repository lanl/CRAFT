# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def rmse(predictions, targets):
    return np.sqrt(((predictions - targets) ** 2).mean())

# %%
Modisexample["date"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-1d1a976de051> in <module>
# ----> 1 Modisexample["date"]
#
# NameError: name 'Modisexample' is not defined

# %%
Modisexample=pd.read_csv("C:/Users/345578/Desktop/Teller_LHS_sampler/output_Teller/obs/Modis_all.csv")
Modisexample["date"]=pd.DatetimeIndex(Modisexample["date"])
simdir="C:/Users/345578/Desktop/Fixedfinally925/outputtest_Teller_Sens_run.IELMFATES/"

# %%
####### PFT1: 

#Teller_Graminoid_D_Shrub_no_comp_daily_043025.IELMFATES_FATES_LAI_CANOPY_SZPF_0_1000
pft1list=list(range(0,9))
last=-1
for i in pft1list:
    print(i)
    sims=pd.read_csv(simdir+"Teller_Sens_run.IELMFATES_FATES_LAI_CANOPY_SZPF_"+str(i)+"_500.csv") 
    
    if i==0:
        sims=sims.iloc[:,[1,4,2]]
        sims["Date"]=pd.DatetimeIndex(sims["Date"])
        sims["Date"]=sims["Date"] - pd.DateOffset(years=69)
        sims=sims[sims["Date"].isin(Modisexample["date"])]
        output=sims
    else: 
        sims=sims.iloc[:,[1,3,2]]
        sims["Date"]=pd.DatetimeIndex(sims["Date"])
        sims["Date"]=sims["Date"] - pd.DateOffset(years=69)
        sims=sims[sims["Date"].isin(Modisexample["date"])]
        output=output.merge(sims,on=["Date","Model"])
        output.iloc[:,2]=output.iloc[:,[2, 3]].sum(axis=1)
        output=output.iloc[:,[0,1,2]]
  #      if last==output["FATES_LAI_CANOPY_SZPF_0"].max():
  #          break
    last=output["FATES_LAI_CANOPY_SZPF_0"].max()
    print(output["FATES_LAI_CANOPY_SZPF_0"].max())
last=-1
pft1list=list(range(0,9))
for i in pft1list:
    print(i)
    sims=pd.read_csv(simdir+"Teller_Sens_run.IELMFATES_FATES_LAI_USTORY_SZPF_"+str(i)+"_500.csv") 
    
    if i==0:
        sims=sims.iloc[:,[1,3,2]]
        sims["Date"]=pd.DatetimeIndex(sims["Date"])
        sims["Date"]=sims["Date"] - pd.DateOffset(years=69)
        sims=sims[sims["Date"].isin(Modisexample["date"])]
        output2=sims
    else: 
        sims=sims.iloc[:,[1,3,2]]
        sims["Date"]=pd.DatetimeIndex(sims["Date"])
        sims["Date"]=sims["Date"] - pd.DateOffset(years=69)
        sims=sims[sims["Date"].isin(Modisexample["date"])]
        output2=output2.merge(sims,on=["Date","Model"])
        output2.iloc[:,2]=output2.iloc[:,[2, 3]].sum(axis=1)
        output2=output2.iloc[:,[0,1,2]]
        print(output2["FATES_LAI_USTORY_SZPF_0"].max())
    #    if last==output2["FATES_LAI_USTORY_SZPF_0"].max():
    #        break
    last=output2["FATES_LAI_USTORY_SZPF_0"].max()
    #print(output["FATES_LAI_USTORY_SZPF_0"].max())
onepft=output.merge(output2,on=["Date","Model"])
onepft.iloc[:,2]=onepft.iloc[:,[2, 3]].sum(axis=1)
onepft=onepft.iloc[:,[0,1,2]]
print(onepft["FATES_LAI_CANOPY_SZPF_0"].max())
onepft.to_csv(simdir+"ProcessedLAI_PFT1.csv")
# Out:
# 0
# 2.2256055
# 1
# 2.2256055
# 2
# 2.2256055
# 3
# 2.2256055
# 4
# 2.2256055
# 5
# 2.2256055
# 6
# 2.2256055
# 7
# 2.2256055
# 8
# 2.2256055
# 0
# 1
# 0.004092024
# 2
# 0.004092024
# 3
# 0.004092024
# 4
# 0.004092024
# 5
# 0.004092024
# 6
# 0.004092024
# 7
# 0.004092024
# 8
# 0.004092024
# 2.2256055

# %%
###PFT 2
pft1list=list(range(12,23))
last=-1
for i in pft1list:
    print(i)
    sims=pd.read_csv(simdir+"Teller_Sens_run.IELMFATES_FATES_LAI_CANOPY_SZPF_"+str(i)+"_500.csv") 
    
    if i==12:
        sims=sims.iloc[:,[1,3,2]]
        sims["Date"]=pd.DatetimeIndex(sims["Date"])
        sims["Date"]=sims["Date"] - pd.DateOffset(years=69)
        sims=sims[sims["Date"].isin(Modisexample["date"])]
        output=sims
    else: 
        sims=sims.iloc[:,[1,3,2]]
        sims["Date"]=pd.DatetimeIndex(sims["Date"])
        sims["Date"]=sims["Date"] - pd.DateOffset(years=69)
        sims=sims[sims["Date"].isin(Modisexample["date"])]
        output=output.merge(sims,on=["Date","Model"])
        output.iloc[:,2]=output.iloc[:,[2, 3]].sum(axis=1)
        output=output.iloc[:,[0,1,2]]
        if last==output["FATES_LAI_CANOPY_SZPF_12"].max():
            break
    last=output["FATES_LAI_CANOPY_SZPF_12"].max()
    print(output["FATES_LAI_CANOPY_SZPF_12"].max())

    
last=-1
pft1list=list(range(12,23))
for i in pft1list:
    print(i)
    sims=pd.read_csv(simdir+"Teller_Sens_run.IELMFATES_FATES_LAI_USTORY_SZPF_"+str(i)+"_500.csv") 
    
    if i==12:
        sims=sims.iloc[:,[1,3,2]]
        sims["Date"]=pd.DatetimeIndex(sims["Date"])
        sims["Date"]=sims["Date"] - pd.DateOffset(years=69)
        sims=sims[sims["Date"].isin(Modisexample["date"])]
        output2=sims
    else: 
        sims=sims.iloc[:,[1,3,2]]
        sims["Date"]=pd.DatetimeIndex(sims["Date"])
        sims["Date"]=sims["Date"] - pd.DateOffset(years=69)
        sims=sims[sims["Date"].isin(Modisexample["date"])]
        output2=output2.merge(sims,on=["Date","Model"])
        output2.iloc[:,2]=output2.iloc[:,[2, 3]].sum(axis=1)
        output2=output2.iloc[:,[0,1,2]]
        if last==output2["FATES_LAI_USTORY_SZPF_12"].max():
            break
    last=output2["FATES_LAI_USTORY_SZPF_12"].max()
    print(output2["FATES_LAI_USTORY_SZPF_12"].max())
    
onepft=output.merge(output2,on=["Date","Model"])
onepft.iloc[:,2]=onepft.iloc[:,[2, 3]].sum(axis=1)
onepft=onepft.iloc[:,[0,1,2]]
onepft["FATES_LAI_CANOPY_SZPF_12"].max()
onepft.to_csv(simdir+"ProcessedLAI_PFT2.csv")
# Out:
# 12
# 0.0
# 13
# 2.043263
# 14
# 12
# 0.0
# 13
# 2.0207343
# 14

# %%
onepft=output.merge(output2,on=["Date","Model"])
onepft.iloc[:,2]=onepft.iloc[:,[2, 3]].sum(axis=1)
onepft.mean()
# Out:
# <ipython-input-5-f124ad4192be>:3: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   onepft.mean()
# Model                      2.501314e+02
# FATES_LAI_CANOPY_SZPF_0    2.683654e-02
# FATES_LAI_USTORY_SZPF_0    1.015283e-07
# dtype: float64

# %%
last=-1
pft1list=list(range(12,23))
for i in pft1list:
    print(i)
    sims=pd.read_csv(simdir+"Teller_Graminoid_D_Shrub_no_comp_daily_043025.IELMFATES_FATES_LAI_USTORY_SZPF_"+str(i)+"_1000.csv") 
    
    if i==12:
        sims=sims.iloc[:,[1,3,2]]
        sims["Date"]=pd.DatetimeIndex(sims["Date"])
        sims["Date"]=sims["Date"] - pd.DateOffset(years=69)
        sims=sims[sims["Date"].isin(Modisexample["date"])]
        output2=sims
    else: 
        sims=sims.iloc[:,[1,3,2]]
        sims["Date"]=pd.DatetimeIndex(sims["Date"])
        sims["Date"]=sims["Date"] - pd.DateOffset(years=69)
        sims=sims[sims["Date"].isin(Modisexample["date"])]
        output2=output2.merge(sims,on=["Date","Model"])
        output2.iloc[:,2]=output2.iloc[:,[2, 3]].sum(axis=1)
        output2=output2.iloc[:,[0,1,2]]
        if last==output2["FATES_LAI_USTORY_SZPF_12"].max():
            break
    last=output2["FATES_LAI_USTORY_SZPF_12"].max()
    
onepft=output.merge(output2,on=["Date","Model"])
onepft.iloc[:,2]=onepft.iloc[:,[2, 3]].sum(axis=1)
onepft=onepft.iloc[:,[0,1,2]]
onepft["FATES_LAI_CANOPY_SZPF_12"].max()
onepft.to_csv(simdir+"ProcessedLAI_PFT2.csv")
# Out:
# 12
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-a8f5d547f9fe> in <module>
#       3 for i in pft1list:
#       4     print(i)
# ----> 5     sims=pd.read_csv(simdir+"Teller_Graminoid_D_Shrub_no_comp_daily_043025.IELMFATES_FATES_LAI_USTORY_SZPF_"+str(i)+"_1000.csv")
#       6
#       7     if i==12:
#
# ~\Anaconda3\envs\NCDF\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
